# %%
import pandas as pd
import numpy as np
import time
from datetime import datetime, timedelta
import re
import os
import shutil

from selenium import webdriver
from selenium.webdriver.support.ui import Select
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains


import warnings
warnings.filterwarnings("ignore")

day = datetime.today()
d = day.day - 2

#---------------------------------------------
#ДНГ POWER BI
#---------------------------------------------
driver = webdriver.Chrome(executable_path = 'C:\\Users\\ADavydovskiy\\scripts\\YandexDriver\\yandexdriver.exe')
x = driver.get('https://app.powerbi.com/groups/me/reports/a88dc325-1805-40fa-9995-e7caff3fa5f8/ReportSection')
time.sleep(5)

#---------------------------------------------

try:
    email = driver.find_element(By.ID, "email")
    email.send_keys("ADavydovskiy@synergy.ru",
                    Keys.ENTER)
except:
    ActionChains(driver) \
        .send_keys("ADavydovskiy@synergy.ru",
                    Keys.ENTER) \
        .perform()

time.sleep(5)

password = driver.find_element(By.ID, "passwordInput")
password.send_keys("Veporu_98765!",
                   Keys.ENTER)

time.sleep(10)

#---------------------------------------------

refresh = driver.find_element(By.XPATH, '//*[@id="reportAppBarRefreshBtn"]/mat-icon')
refresh.click()

time.sleep(10)

#---------------------------------------------

save_0 = driver.find_element(By.ID, "exportMenuBtn")
save_0.click()
time.sleep(3)

save_1 = driver.find_element(By.XPATH, '//*[@id="mat-menu-panel-2"]/div/button[3]')
save_1.click()
time.sleep(3)

save_2 = driver.find_element(By.XPATH, '//*[@id="mat-dialog-0"]/export-report-dialog/form/template-dialog/dialog-body/mat-dialog-content/div/pbi-checkbox[2]/div/label/div')
save_2.click()
time.sleep(3)

save_3 = driver.find_element(By.ID, 'okButton')
save_3.click()

time.sleep(60)
driver.close()
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Input In [1], in <cell line: 66>()
#      63 save_1.click()
#      64 time.sleep(3)
# ---> 66 save_2 = driver.find_element(By.XPATH, '//*[@id="mat-dialog-0"]/export-report-dialog/form/template-dialog/dialog-body/mat-dialog-content/div/pbi-checkbox[2]/div/label/div')
#      67 save_2.click()
#      68 time.sleep(3)
#
# File ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:976, in WebDriver.find_element(self, by, value)
#     974         by = By.CSS_SELECTOR
#     975         value = '[name="%s"]' % value
# --> 976 return self.execute(Command.FIND_ELEMENT, {
#     977     'using': by,
#     978     'value': value})['value']
#
# File ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:321, in WebDriver.execute(self, driver_command, params)
# ...
